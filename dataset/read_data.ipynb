# %%
import os
import pandas as pd
import scipy

# %%
from skmultilearn.dataset import load_dataset

# %%
X_train, y_train, feature_name, label_name = load_dataset('emotions','train')
# Out:
# emotions:train - exists, not redownloading

# %%
X_test, y_test, _, _ = load_dataset('emotions','test')
# Out:
# emotions:test - does not exists downloading
# Downloaded emotions-test

# %%
# Import BinaryRelevance from skmultilearn
from skmultilearn.problem_transform import BinaryRelevance

# Import SVC classifier from sklearn
from sklearn.svm import SVC

# Setup the classifier
classifier = BinaryRelevance(classifier=SVC(), require_dense=[False,True])

# Train
classifier.fit(X_train, y_train)

# Predict
y_pred = classifier.predict(X_test)

# %%
def print_label(item):
    z=[]
    for i in len(label_name):
        if(i)
# Out:
# True

# %%
result = y_train.todense()
for i in range(result.shape[0]):
    z=[]
    for j in range(result.shape[1]):
        if result[i,j] == 1:
            z.append(label_name[j][0])
    if (len(z)):
        print(i, "label:", z)
# Out:
# 0 label: ['happy-pleased', 'relaxing-calm']
# 1 label: ['amazed-suprised', 'angry-aggresive']
# 2 label: ['happy-pleased', 'angry-aggresive']
# 3 label: ['relaxing-calm']
# 4 label: ['quiet-still']
# 5 label: ['happy-pleased', 'relaxing-calm']
# 6 label: ['amazed-suprised', 'happy-pleased']
# 7 label: ['angry-aggresive']
# 8 label: ['amazed-suprised', 'happy-pleased']
# 9 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 10 label: ['happy-pleased', 'relaxing-calm']
# 11 label: ['relaxing-calm']
# 12 label: ['amazed-suprised']
# 13 label: ['relaxing-calm', 'sad-lonely']
# 14 label: ['sad-lonely']
# 15 label: ['amazed-suprised', 'angry-aggresive']
# 16 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 17 label: ['happy-pleased', 'relaxing-calm']
# 18 label: ['sad-lonely', 'angry-aggresive']
# 19 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 20 label: ['amazed-suprised', 'angry-aggresive']
# 21 label: ['happy-pleased']
# 22 label: ['happy-pleased']
# 23 label: ['angry-aggresive']
# 24 label: ['angry-aggresive']
# 25 label: ['relaxing-calm', 'angry-aggresive']
# 26 label: ['relaxing-calm']
# 27 label: ['amazed-suprised', 'happy-pleased', 'angry-aggresive']
# 28 label: ['happy-pleased']
# 29 label: ['relaxing-calm']
# 30 label: ['angry-aggresive']
# 31 label: ['relaxing-calm', 'quiet-still']
# 32 label: ['amazed-suprised', 'angry-aggresive']
# 33 label: ['angry-aggresive']
# 34 label: ['amazed-suprised', 'happy-pleased']
# 35 label: ['happy-pleased', 'relaxing-calm']
# 36 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 37 label: ['happy-pleased', 'relaxing-calm']
# 38 label: ['amazed-suprised', 'happy-pleased']
# 39 label: ['amazed-suprised', 'angry-aggresive']
# 40 label: ['happy-pleased']
# 41 label: ['amazed-suprised', 'sad-lonely']
# 42 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 43 label: ['happy-pleased', 'relaxing-calm']
# 44 label: ['amazed-suprised', 'happy-pleased']
# 45 label: ['happy-pleased', 'relaxing-calm']
# 46 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 47 label: ['happy-pleased', 'relaxing-calm']
# 48 label: ['angry-aggresive']
# 49 label: ['amazed-suprised', 'angry-aggresive']
# 50 label: ['angry-aggresive']
# 51 label: ['relaxing-calm', 'sad-lonely', 'angry-aggresive']
# 52 label: ['angry-aggresive']
# 53 label: ['amazed-suprised', 'angry-aggresive']
# 54 label: ['amazed-suprised', 'angry-aggresive']
# 55 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 56 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 57 label: ['relaxing-calm', 'sad-lonely']
# 58 label: ['amazed-suprised', 'happy-pleased']
# 59 label: ['happy-pleased', 'sad-lonely']
# 60 label: ['sad-lonely', 'angry-aggresive']
# 61 label: ['happy-pleased', 'relaxing-calm']
# 62 label: ['relaxing-calm', 'quiet-still']
# 63 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 64 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 65 label: ['amazed-suprised', 'angry-aggresive']
# 66 label: ['relaxing-calm']
# 67 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 68 label: ['happy-pleased', 'relaxing-calm']
# 69 label: ['amazed-suprised', 'angry-aggresive']
# 70 label: ['sad-lonely']
# 71 label: ['amazed-suprised', 'angry-aggresive']
# 72 label: ['angry-aggresive']
# 73 label: ['amazed-suprised', 'happy-pleased', 'relaxing-calm']
# 74 label: ['amazed-suprised', 'relaxing-calm']
# 75 label: ['relaxing-calm', 'sad-lonely', 'angry-aggresive']
# 76 label: ['happy-pleased', 'relaxing-calm']
# 77 label: ['happy-pleased', 'relaxing-calm']
# 78 label: ['angry-aggresive']
# 79 label: ['angry-aggresive']
# 80 label: ['angry-aggresive']
# 81 label: ['amazed-suprised']
# 82 label: ['relaxing-calm', 'sad-lonely']
# 83 label: ['amazed-suprised']
# 84 label: ['relaxing-calm']
# 85 label: ['relaxing-calm', 'quiet-still']
# 86 label: ['relaxing-calm', 'sad-lonely']
# 87 label: ['relaxing-calm', 'quiet-still']
# 88 label: ['angry-aggresive']
# 89 label: ['happy-pleased', 'angry-aggresive']
# 90 label: ['sad-lonely']
# 91 label: ['amazed-suprised', 'angry-aggresive']
# 92 label: ['relaxing-calm', 'sad-lonely']
# 93 label: ['happy-pleased', 'relaxing-calm']
# 94 label: ['amazed-suprised', 'angry-aggresive']
# 95 label: ['angry-aggresive']
# 96 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 97 label: ['amazed-suprised', 'angry-aggresive']
# 98 label: ['angry-aggresive']
# 99 label: ['amazed-suprised', 'happy-pleased']
# 100 label: ['relaxing-calm']
# 101 label: ['angry-aggresive']
# 102 label: ['angry-aggresive']
# 103 label: ['relaxing-calm']
# 104 label: ['amazed-suprised', 'angry-aggresive']
# 105 label: ['happy-pleased', 'relaxing-calm']
# 106 label: ['amazed-suprised', 'angry-aggresive']
# 107 label: ['amazed-suprised', 'happy-pleased']
# 108 label: ['angry-aggresive']
# 109 label: ['amazed-suprised']
# 110 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 111 label: ['amazed-suprised', 'angry-aggresive']
# 112 label: ['angry-aggresive']
# 113 label: ['sad-lonely', 'angry-aggresive']
# 114 label: ['happy-pleased', 'relaxing-calm', 'quiet-still']
# 115 label: ['happy-pleased', 'relaxing-calm']
# 116 label: ['amazed-suprised', 'happy-pleased', 'angry-aggresive']
# 117 label: ['relaxing-calm', 'sad-lonely']
# 118 label: ['relaxing-calm', 'sad-lonely']
# 119 label: ['relaxing-calm', 'angry-aggresive']
# 120 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 121 label: ['angry-aggresive']
# 122 label: ['happy-pleased', 'relaxing-calm']
# 123 label: ['amazed-suprised', 'angry-aggresive']
# 124 label: ['quiet-still', 'sad-lonely']
# 125 label: ['happy-pleased', 'relaxing-calm']
# 126 label: ['amazed-suprised', 'angry-aggresive']
# 127 label: ['relaxing-calm', 'quiet-still']
# 128 label: ['angry-aggresive']
# 129 label: ['amazed-suprised']
# 130 label: ['happy-pleased', 'relaxing-calm']
# 131 label: ['amazed-suprised', 'happy-pleased']
# 132 label: ['happy-pleased', 'relaxing-calm']
# 133 label: ['sad-lonely', 'angry-aggresive']
# 134 label: ['amazed-suprised']
# 135 label: ['angry-aggresive']
# 136 label: ['amazed-suprised']
# 137 label: ['happy-pleased', 'relaxing-calm']
# 138 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 139 label: ['amazed-suprised', 'angry-aggresive']
# 140 label: ['relaxing-calm', 'sad-lonely']
# 141 label: ['angry-aggresive']
# 142 label: ['relaxing-calm']
# 143 label: ['amazed-suprised', 'angry-aggresive']
# 144 label: ['amazed-suprised', 'angry-aggresive']
# 145 label: ['amazed-suprised', 'happy-pleased']
# 146 label: ['happy-pleased']
# 147 label: ['amazed-suprised']
# 148 label: ['amazed-suprised', 'angry-aggresive']
# 149 label: ['angry-aggresive']
# 150 label: ['happy-pleased']
# 151 label: ['amazed-suprised']
# 152 label: ['quiet-still', 'sad-lonely']
# 153 label: ['amazed-suprised', 'angry-aggresive']
# 154 label: ['amazed-suprised', 'angry-aggresive']
# 155 label: ['happy-pleased', 'relaxing-calm', 'quiet-still']
# 156 label: ['relaxing-calm', 'sad-lonely']
# 157 label: ['quiet-still', 'sad-lonely']
# 158 label: ['angry-aggresive']
# 159 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 160 label: ['angry-aggresive']
# 161 label: ['angry-aggresive']
# 162 label: ['happy-pleased']
# 163 label: ['relaxing-calm']
# 164 label: ['amazed-suprised', 'angry-aggresive']
# 165 label: ['angry-aggresive']
# 166 label: ['relaxing-calm', 'sad-lonely']
# 167 label: ['angry-aggresive']
# 168 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 169 label: ['angry-aggresive']
# 170 label: ['amazed-suprised']
# 171 label: ['relaxing-calm', 'sad-lonely']
# 172 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 173 label: ['angry-aggresive']
# 174 label: ['angry-aggresive']
# 175 label: ['amazed-suprised', 'angry-aggresive']
# 176 label: ['angry-aggresive']
# 177 label: ['happy-pleased']
# 178 label: ['amazed-suprised']
# 179 label: ['happy-pleased', 'relaxing-calm']
# 180 label: ['amazed-suprised', 'angry-aggresive']
# 181 label: ['relaxing-calm']
# 182 label: ['happy-pleased', 'relaxing-calm']
# 183 label: ['angry-aggresive']
# 184 label: ['amazed-suprised']
# 185 label: ['happy-pleased']
# 186 label: ['quiet-still', 'sad-lonely']
# 187 label: ['relaxing-calm', 'quiet-still']
# 188 label: ['happy-pleased', 'relaxing-calm']
# 189 label: ['relaxing-calm']
# 190 label: ['happy-pleased']
# 191 label: ['happy-pleased', 'relaxing-calm']
# 192 label: ['amazed-suprised', 'angry-aggresive']
# 193 label: ['relaxing-calm']
# 194 label: ['relaxing-calm', 'quiet-still']
# 195 label: ['happy-pleased', 'relaxing-calm']
# 196 label: ['amazed-suprised', 'angry-aggresive']
# 197 label: ['amazed-suprised', 'angry-aggresive']
# 198 label: ['happy-pleased']
# 199 label: ['sad-lonely']
# 200 label: ['amazed-suprised', 'happy-pleased', 'relaxing-calm']
# 201 label: ['amazed-suprised']
# 202 label: ['relaxing-calm', 'sad-lonely']
# 203 label: ['angry-aggresive']
# 204 label: ['relaxing-calm', 'sad-lonely']
# 205 label: ['angry-aggresive']
# 206 label: ['amazed-suprised', 'happy-pleased']
# 207 label: ['quiet-still']
# 208 label: ['angry-aggresive']
# 209 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 210 label: ['happy-pleased']
# 211 label: ['amazed-suprised', 'angry-aggresive']
# 212 label: ['amazed-suprised', 'angry-aggresive']
# 213 label: ['angry-aggresive']
# 214 label: ['amazed-suprised']
# 215 label: ['sad-lonely']
# 216 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 217 label: ['amazed-suprised', 'angry-aggresive']
# 218 label: ['quiet-still', 'sad-lonely']
# 219 label: ['angry-aggresive']
# 220 label: ['amazed-suprised', 'angry-aggresive']
# 221 label: ['angry-aggresive']
# 222 label: ['happy-pleased', 'relaxing-calm']
# 223 label: ['relaxing-calm']
# 224 label: ['happy-pleased', 'relaxing-calm', 'quiet-still']
# 225 label: ['angry-aggresive']
# 226 label: ['angry-aggresive']
# 227 label: ['amazed-suprised', 'angry-aggresive']
# 228 label: ['happy-pleased', 'relaxing-calm']
# 229 label: ['amazed-suprised']
# 230 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 231 label: ['amazed-suprised']
# 232 label: ['happy-pleased', 'relaxing-calm']
# 233 label: ['amazed-suprised', 'happy-pleased']
# 234 label: ['relaxing-calm', 'quiet-still']
# 235 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 236 label: ['happy-pleased', 'relaxing-calm']
# 237 label: ['angry-aggresive']
# 238 label: ['happy-pleased']
# 239 label: ['happy-pleased']
# 240 label: ['happy-pleased', 'relaxing-calm']
# 241 label: ['angry-aggresive']
# 242 label: ['amazed-suprised', 'happy-pleased']
# 243 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 244 label: ['relaxing-calm', 'quiet-still']
# 245 label: ['amazed-suprised', 'angry-aggresive']
# 246 label: ['amazed-suprised', 'angry-aggresive']
# 247 label: ['amazed-suprised', 'happy-pleased']
# 248 label: ['happy-pleased']
# 249 label: ['happy-pleased', 'relaxing-calm']
# 250 label: ['amazed-suprised', 'happy-pleased', 'relaxing-calm']
# 251 label: ['relaxing-calm']
# 252 label: ['quiet-still']
# 253 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 254 label: ['amazed-suprised', 'happy-pleased', 'relaxing-calm']
# 255 label: ['happy-pleased', 'quiet-still']
# 256 label: ['relaxing-calm', 'sad-lonely']
# 257 label: ['amazed-suprised', 'angry-aggresive']
# 258 label: ['amazed-suprised', 'happy-pleased']
# 259 label: ['amazed-suprised', 'angry-aggresive']
# 260 label: ['amazed-suprised', 'happy-pleased']
# 261 label: ['angry-aggresive']
# 262 label: ['amazed-suprised', 'angry-aggresive']
# 263 label: ['amazed-suprised', 'happy-pleased']
# 264 label: ['amazed-suprised', 'angry-aggresive']
# 265 label: ['amazed-suprised', 'angry-aggresive']
# 266 label: ['happy-pleased', 'relaxing-calm', 'quiet-still']
# 267 label: ['amazed-suprised', 'angry-aggresive']
# 268 label: ['relaxing-calm', 'sad-lonely']
# 269 label: ['relaxing-calm', 'quiet-still']
# 270 label: ['sad-lonely', 'angry-aggresive']
# 271 label: ['happy-pleased', 'relaxing-calm']
# 272 label: ['relaxing-calm', 'quiet-still']
# 273 label: ['angry-aggresive']
# 274 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 275 label: ['amazed-suprised']
# 276 label: ['happy-pleased', 'relaxing-calm']
# 277 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 278 label: ['amazed-suprised', 'angry-aggresive']
# 279 label: ['amazed-suprised', 'angry-aggresive']
# 280 label: ['relaxing-calm', 'sad-lonely']
# 281 label: ['angry-aggresive']
# 282 label: ['amazed-suprised', 'happy-pleased']
# 283 label: ['amazed-suprised', 'relaxing-calm']
# 284 label: ['amazed-suprised', 'angry-aggresive']
# 285 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 286 label: ['relaxing-calm', 'quiet-still']
# 287 label: ['relaxing-calm']
# 288 label: ['angry-aggresive']
# 289 label: ['sad-lonely', 'angry-aggresive']
# 290 label: ['relaxing-calm', 'sad-lonely']
# 291 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 292 label: ['amazed-suprised', 'angry-aggresive']
# 293 label: ['angry-aggresive']
# 294 label: ['sad-lonely']
# 295 label: ['relaxing-calm', 'quiet-still', 'angry-aggresive']
# 296 label: ['amazed-suprised', 'angry-aggresive']
# 297 label: ['amazed-suprised', 'sad-lonely']
# 298 label: ['relaxing-calm']
# 299 label: ['quiet-still', 'sad-lonely']
# 300 label: ['quiet-still', 'sad-lonely']
# 301 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 302 label: ['quiet-still', 'sad-lonely']
# 303 label: ['amazed-suprised', 'sad-lonely']
# 304 label: ['amazed-suprised', 'angry-aggresive']
# 305 label: ['amazed-suprised', 'happy-pleased']
# 306 label: ['amazed-suprised', 'sad-lonely']
# 307 label: ['relaxing-calm', 'quiet-still']
# 308 label: ['happy-pleased', 'relaxing-calm']
# 309 label: ['happy-pleased', 'relaxing-calm']
# 310 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 311 label: ['amazed-suprised', 'angry-aggresive']
# 312 label: ['relaxing-calm']
# 313 label: ['angry-aggresive']
# 314 label: ['relaxing-calm', 'quiet-still']
# 315 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 316 label: ['quiet-still']
# 317 label: ['relaxing-calm', 'quiet-still']
# 318 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 319 label: ['amazed-suprised', 'angry-aggresive']
# 320 label: ['relaxing-calm', 'quiet-still']
# 321 label: ['relaxing-calm', 'quiet-still']
# 322 label: ['relaxing-calm']
# 323 label: ['happy-pleased', 'relaxing-calm']
# 324 label: ['quiet-still', 'sad-lonely']
# 325 label: ['quiet-still', 'sad-lonely']
# 326 label: ['amazed-suprised', 'happy-pleased']
# 327 label: ['happy-pleased', 'relaxing-calm']
# 328 label: ['amazed-suprised']
# 329 label: ['amazed-suprised', 'angry-aggresive']
# 330 label: ['relaxing-calm']
# 331 label: ['angry-aggresive']
# 332 label: ['happy-pleased', 'relaxing-calm']
# 333 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 334 label: ['happy-pleased', 'relaxing-calm']
# 335 label: ['relaxing-calm', 'quiet-still']
# 336 label: ['quiet-still']
# 337 label: ['amazed-suprised', 'happy-pleased']
# 338 label: ['relaxing-calm']
# 339 label: ['angry-aggresive']
# 340 label: ['amazed-suprised', 'angry-aggresive']
# 341 label: ['happy-pleased']
# 342 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 343 label: ['sad-lonely']
# 344 label: ['happy-pleased', 'relaxing-calm']
# 345 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 346 label: ['relaxing-calm']
# 347 label: ['amazed-suprised']
# 348 label: ['relaxing-calm', 'quiet-still']
# 349 label: ['relaxing-calm', 'quiet-still']
# 350 label: ['quiet-still', 'sad-lonely']
# 351 label: ['quiet-still', 'sad-lonely']
# 352 label: ['angry-aggresive']
# 353 label: ['angry-aggresive']
# 354 label: ['relaxing-calm', 'sad-lonely']
# 355 label: ['happy-pleased']
# 356 label: ['amazed-suprised', 'happy-pleased', 'relaxing-calm']
# 357 label: ['amazed-suprised', 'happy-pleased', 'relaxing-calm']
# 358 label: ['quiet-still', 'sad-lonely']
# 359 label: ['amazed-suprised', 'happy-pleased']
# 360 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 361 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 362 label: ['relaxing-calm', 'quiet-still']
# 363 label: ['happy-pleased', 'angry-aggresive']
# 364 label: ['amazed-suprised', 'happy-pleased', 'relaxing-calm']
# 365 label: ['amazed-suprised', 'angry-aggresive']
# 366 label: ['amazed-suprised', 'happy-pleased']
# 367 label: ['amazed-suprised', 'happy-pleased', 'angry-aggresive']
# 368 label: ['happy-pleased', 'relaxing-calm']
# 369 label: ['relaxing-calm']
# 370 label: ['quiet-still', 'sad-lonely']
# 371 label: ['amazed-suprised']
# 372 label: ['happy-pleased', 'relaxing-calm', 'quiet-still']
# 373 label: ['amazed-suprised', 'angry-aggresive']
# 374 label: ['amazed-suprised']
# 375 label: ['happy-pleased', 'relaxing-calm']
# 376 label: ['relaxing-calm', 'sad-lonely']
# 377 label: ['quiet-still', 'sad-lonely', 'angry-aggresive']
# 378 label: ['relaxing-calm']
# 379 label: ['amazed-suprised', 'angry-aggresive']
# 380 label: ['amazed-suprised']
# 381 label: ['happy-pleased', 'relaxing-calm']
# 382 label: ['happy-pleased']
# 383 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 384 label: ['quiet-still', 'sad-lonely']
# 385 label: ['relaxing-calm', 'quiet-still', 'sad-lonely']
# 386 label: ['angry-aggresive']
# 387 label: ['amazed-suprised', 'angry-aggresive']
# 388 label: ['happy-pleased', 'relaxing-calm']
# 389 label: ['quiet-still', 'sad-lonely']
# 390 label: ['happy-pleased', 'relaxing-calm']
